# %% [markdown]
# # 클래스 분포 확인

# %%
import pandas as pd

df = pd.read_csv("./data/train/train.csv")
print(df)
# Out:
#           id  gender   race  age                    path
# 0     000001  female  Asian   45  000001_female_Asian_45
# 1     000002  female  Asian   52  000002_female_Asian_52
# 2     000004    male  Asian   54    000004_male_Asian_54
# 3     000005  female  Asian   58  000005_female_Asian_58
# 4     000006  female  Asian   59  000006_female_Asian_59
# ...      ...     ...    ...  ...                     ...
# 2695  006954    male  Asian   19    006954_male_Asian_19
# 2696  006955    male  Asian   19    006955_male_Asian_19
# 2697  006956    male  Asian   19    006956_male_Asian_19
# 2698  006957    male  Asian   20    006957_male_Asian_20
# 2699  006959    male  Asian   19    006959_male_Asian_19
#
# [2700 rows x 5 columns]

# %%
df['label']=0
df['age']==df['age'].astype(int)
print(df)
# Out:
#           id  gender   race  age                    path  label
# 0     000001  female  Asian   45  000001_female_Asian_45      0
# 1     000002  female  Asian   52  000002_female_Asian_52      0
# 2     000004    male  Asian   54    000004_male_Asian_54      0
# 3     000005  female  Asian   58  000005_female_Asian_58      0
# 4     000006  female  Asian   59  000006_female_Asian_59      0
# ...      ...     ...    ...  ...                     ...    ...
# 2695  006954    male  Asian   19    006954_male_Asian_19      0
# 2696  006955    male  Asian   19    006955_male_Asian_19      0
# 2697  006956    male  Asian   19    006956_male_Asian_19      0
# 2698  006957    male  Asian   20    006957_male_Asian_20      0
# 2699  006959    male  Asian   19    006959_male_Asian_19      0
#
# [2700 rows x 6 columns]

# %%
df.loc[(df['gender']=='male')&(df['age']<30),'label']=0
df.loc[(df['gender']=='male')&(df['age']>=30) & (df['age']<60),'label']=1
df.loc[(df['gender']=='male')&(df['age']>=60),'label']=2
df.loc[(df['gender']=='female')&(df['age']<30),'label']=3
df.loc[(df['gender']=='female')&(df['age']>=30) & (df['age']<60),'label']=4
df.loc[(df['gender']=='female')&(df['age']>=60),'label']=5
print(df)
# Out:
#           id  gender   race  age                    path  label
# 0     000001  female  Asian   45  000001_female_Asian_45      4
# 1     000002  female  Asian   52  000002_female_Asian_52      4
# 2     000004    male  Asian   54    000004_male_Asian_54      1
# 3     000005  female  Asian   58  000005_female_Asian_58      4
# 4     000006  female  Asian   59  000006_female_Asian_59      4
# ...      ...     ...    ...  ...                     ...    ...
# 2695  006954    male  Asian   19    006954_male_Asian_19      0
# 2696  006955    male  Asian   19    006955_male_Asian_19      0
# 2697  006956    male  Asian   19    006956_male_Asian_19      0
# 2698  006957    male  Asian   20    006957_male_Asian_20      0
# 2699  006959    male  Asian   19    006959_male_Asian_19      0
#
# [2700 rows x 6 columns]

# %%
df['count']=1
df_label=df[['label','count']].copy()
df_label=df_label.groupby('label').count()
print(df_label)
# Out:
#        count
# label
# 0        549
# 1        410
# 2         83
# 3        732
# 4        817
# 5        109

# %%
df_label.loc[0,"count"]
# Out:
# 549

# %%
df_folds = df[['path','label']].copy()
print(df_folds)
# Out:
#                         path  label
# 0     000001_female_Asian_45      4
# 1     000002_female_Asian_52      4
# 2       000004_male_Asian_54      1
# 3     000005_female_Asian_58      4
# 4     000006_female_Asian_59      4
# ...                      ...    ...
# 2695    006954_male_Asian_19      0
# 2696    006955_male_Asian_19      0
# 2697    006956_male_Asian_19      0
# 2698    006957_male_Asian_20      0
# 2699    006959_male_Asian_19      0
#
# [2700 rows x 2 columns]

# %%
print(df_folds[df_folds.loc[:,'path']=='000001_female_Asian_45'])
# Out:
#                      path  label
# 0  000001_female_Asian_45      4

# %%
print(list(df_folds['path']))
# Out:
# ['000001_female_Asian_45', '000002_female_Asian_52', '000004_male_Asian_54', '000005_female_Asian_58', '000006_female_Asian_59', '000007_female_Asian_58', '000008_female_Asian_58', '000009_female_Asian_56', '000010_female_Asian_58', '000012_male_Asian_57', '000014_female_Asian_58', '000015_male_Asian_55', '000016_female_Asian_58', '000018_female_Asian_59', '000019_female_Asian_57', '000020_female_Asian_50', '000021_female_Asian_54', '000022_female_Asian_58', '000023_female_Asian_55', '000024_female_Asian_58', '000025_female_Asian_49', '000026_female_Asian_56', '000028_female_Asian_58', '000029_female_Asian_58', '000030_female_Asian_55', '000031_female_Asian_54', '000033_male_Asian_57', '000034_female_Asian_55', '000036_female_Asian_58', '000037_female_Asian_58', '000038_female_Asian_58', '000039_female_Asian_57', '000040_female_Asian_57', '000041_female_Asian_58', '000043_male_Asian_56', '000044_female_Asian_58', '000045_female_Asian_56', '000046_male_Asian_55', '000047_male_Asian_58', '000048_female_Asian_57', '000062_female_Asian_55', '000064_male_Asian_59', '000066_female_Asian_53', '000067_female_Asian_54', '000069_female_Asian_54', '000070_female_Asian_58', '000071_female_Asian_56', '000073_female_Asian_52', '000075_female_Asian_56', '000077_male_Asian_59', '000078_female_Asian_55', '000079_female_Asian_57', '000080_female_Asian_57', '000206_female_Asian_57', '000207_female_Asian_56', '000209_female_Asian_56', '000210_female_Asian_54', '000212_female_Asian_51', '000214_female_Asian_51', '000215_female_Asian_59', '000216_female_Asian_56', '000217_female_Asian_54', '000218_female_Asian_59', '000219_female_Asian_53', '000221_female_Asian_40', '000224_female_Asian_56', '000225_female_Asian_25', '000226_female_Asian_58', '000227_female_Asian_59', '000228_female_Asian_56', '000229_male_Asian_56', '000231_male_Asian_56', '000232_male_Asian_53', '000235_male_Asian_57', '000236_male_Asian_51', '000237_male_Asian_56', '000238_male_Asian_57', '000240_male_Asian_57', '000241_male_Asian_56', '000242_male_Asian_56', '000243_female_Asian_58', '000244_female_Asian_56', '000245_male_Asian_58', '000248_female_Asian_54', '000249_male_Asian_53', '000255_female_Asian_59', '000256_female_Asian_58', '000260_female_Asian_58', '000261_female_Asian_58', '000262_male_Asian_56', '000263_female_Asian_48', '000264_female_Asian_51', '000265_female_Asian_58', '000266_female_Asian_58', '000267_male_Asian_58', '000268_male_Asian_59', '000269_male_Asian_56', '000270_female_Asian_49', '000272_female_Asian_52', '000273_female_Asian_56', '000274_female_Asian_54', '000275_female_Asian_54', '000276_female_Asian_58', '000277_female_Asian_54', '000278_female_Asian_54', '000279_female_Asian_54', '000280_female_Asian_54', '000282_female_Asian_59', '000283_female_Asian_57', '000285_female_Asian_54', '000286_female_Asian_51', '000288_female_Asian_51', '000292_female_Asian_57', '000293_female_Asian_57', '000294_female_Asian_53', '000295_female_Asian_56', '000296_female_Asian_57', '000297_female_Asian_53', '000299_female_Asian_57', '000301_female_Asian_55', '000302_female_Asian_56', '000304_female_Asian_51', '000309_male_Asian_29', '000311_female_Asian_58', '000312_female_Asian_57', '000313_female_Asian_54', '000334_female_Asian_52', '000336_female_Asian_56', '000344_female_Asian_57', '000348_male_Asian_58', '000356_female_Asian_58', '000357_female_Asian_55', '000376_female_Asian_59', '000378_female_Asian_55', '000381_female_Asian_59', '000498_female_Asian_56', '000499_female_Asian_58', '000511_female_Asian_55', '000512_female_Asian_55', '000513_female_Asian_58', '000514_female_Asian_59', '000515_female_Asian_50', '000516_female_Asian_52', '000517_female_Asian_58', '000518_female_Asian_55', '000519_female_Asian_56', '000520_female_Asian_59', '000522_female_Asian_51', '000523_female_Asian_51', '000525_female_Asian_53', '000526_female_Asian_59', '000527_female_Asian_58', '000528_female_Asian_51', '000529_female_Asian_51', '000531_female_Asian_56', '000532_female_Asian_57 ...

# %% [markdown]
# # stratified Group K-Fold

# %%
from collections import defaultdict
import numpy as np
import random

seed=2022
k=5

path_list=list(df_folds['path'])
label_list=list(df_folds['label'])
path_to_label=dict()

for a,b in zip(path_list,label_list):
    path_to_label[a]=b
    
labels_num = 6
class_counts_per_fold = defaultdict(lambda:np.zeros(labels_num))

def eval_class_counts_per_fold(image_path,fold,k):
    class_counts_per_fold[fold][path_to_label[image_path]] += 1
    std_per_class=[]
    for class_number in range(labels_num):
        class_std = np.std([class_counts_per_fold[i][class_number]/df_label.loc[class_number,'count'] for i in range(k)])
        std_per_class.append(class_std)
    class_counts_per_fold[fold][path_to_label[image_path]] -= 1
    
    return np.mean(std_per_class)


image_names_per_fold = defaultdict(set)

random.Random(seed).shuffle(path_list)

for image_path in path_list:
    best_fold = None
    min_eval = None
    for i in range(k):
        fold_eval = eval_class_counts_per_fold(image_path,i,k)
        if min_eval is None or fold_eval < min_eval:
            min_eval = fold_eval
            best_fold = i
    class_counts_per_fold[best_fold][path_to_label[image_path]]+=1
    image_names_per_fold[best_fold].add(image_path)

all_image_names = set(path_list)

k_fold_train_test_list=[]

for i in range(k):
    train_image_names = all_image_names - image_names_per_fold[i]
    test_image_names = image_names_per_fold[i]
    
    k_fold_train_test_list.append((list(train_image_names),list(test_image_names)))

# %%
print(f'fold0 train 개수 : {len(k_fold_train_test_list[0][0])}, valid 개수 : {len(k_fold_train_test_list[0][1])}')
print(f'fold1 train 개수 : {len(k_fold_train_test_list[1][0])}, valid 개수 : {len(k_fold_train_test_list[1][1])}')
print(f'fold2 train 개수 : {len(k_fold_train_test_list[2][0])}, valid 개수 : {len(k_fold_train_test_list[2][1])}')
print(f'fold3 train 개수 : {len(k_fold_train_test_list[3][0])}, valid 개수 : {len(k_fold_train_test_list[3][1])}')
print(f'fold4 train 개수 : {len(k_fold_train_test_list[4][0])}, valid 개수 : {len(k_fold_train_test_list[4][1])}')
# Out:
# fold0 train 개수 : 2158, valid 개수 : 542
# fold1 train 개수 : 2158, valid 개수 : 542
# fold2 train 개수 : 2160, valid 개수 : 540
# fold3 train 개수 : 2161, valid 개수 : 539
# fold4 train 개수 : 2163, valid 개수 : 537

# %%
k_fold={}
k_fold[0]=(list(k_fold_train_test_list[0]))
k_fold[1]=(list(k_fold_train_test_list[1]))
k_fold[2]=(list(k_fold_train_test_list[2]))
k_fold[3]=(list(k_fold_train_test_list[3]))
k_fold[4]=(list(k_fold_train_test_list[4]))

# %%
import json

with open('stratified_k_fold_dict.json','w') as f:
    json.dump(k_fold,f,indent=4)
